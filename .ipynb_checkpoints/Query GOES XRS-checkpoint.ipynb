# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

#from sunpy import timeseries as ts
from sunpy.net import Fido
from sunpy.net import attrs as a

from sunpy.timeseries import TimeSeries

# %%
### To test sunpy correctly install
#import sunpy
#sunpy.self_test()

# %%
pwd
# Out:
# '/Users/Mila/Desktop/Solar_Flare/Solar_Flare'

# %%
tstart = '2022-04-25 01:00'
tend = '2022-04-25 23:00'

result_goes16 = Fido.search(a.Time(tstart,tend), a.Instrument('XRS'),a.goes.SatelliteNumber(16))
result_goes17 = Fido.search(a.Time(tstart,tend), a.Instrument('XRS'),a.goes.SatelliteNumber(17))
#,a.goes.SatelliteNumber(16)
print(result_goes16)
# Out:
# Results from 1 Provider:
#
# 1 Results from the XRSClient:
# Source: https://umbra.nascom.nasa.gov/goes/fits
#
#        Start Time               End Time        Instrument ... Source Provider
# ----------------------- ----------------------- ---------- ... ------ --------
# 2022-04-25 00:00:00.000 2022-04-25 23:59:59.999        XRS ...   GOES     NOAA

# %%
pwd
# Out:
# '/Users/Mila/Desktop/Solar_Flare/Solar_Flare'

# %%
file_goes16 = Fido.fetch(result_goes16,path='/Users/Mila/Desktop/Solar_Flare/Solar_Flare')
file_goes17 = Fido.fetch(result_goes17,path='/Users/Mila/Desktop/Solar_Flare/Solar_Flare')
# Out:
# ...
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]

# %%
goes16 = TimeSeries(file_goes16, concatenate=True)
goes17 = TimeSeries(file_goes17, concatenate=True)

# %%
goes16
# Out:
# ...
# |-------------------------------------------------------------------------------------------------|
# |TimeRange                  | Columns         | Meta                                              |
# |-------------------------------------------------------------------------------------------------|
# |2022-04-24T23:59:59.776181 | xrsa            | conventions: ACDD-1.3, Spase v2.2.6               |
# |            to             | xrsb            | title: L2 XRS 1-s fluxes                          |
# |2022-04-25T23:59:59.025029 |                 | summary: The X-Ray 1s flux product consists of hig|
# |                           |                 | keywords: NumericalData.MeasurementType.Irradiance|
# |                           |                 | keywords_vocabulary: SPASE: Space Physics Archive |
# |                           |                 | naming_authority: gov.nesdis.noaa                 |
# ...

# %% [markdown]
# **The base line of the data for the satellite goes 17 and 16 in the long wavelength belongs to the classification type C while in the short wavelength it is between type A and B.**

# %%
serie16 = goes16.to_dataframe()
serie17 = goes17.to_dataframe()

# %%
serie16.index = serie16.index.floor('s')
serie17.index = serie17.index.floor('s')

# %%
serie16 = serie16.add_suffix('_16')
serie17 = serie17.add_suffix('_17')

# %%
XRS = pd.concat([serie16,serie17], axis=1)
## Examine the DataFrame /inspect data
XRS.head()
# Out:
#                           xrsa_16   xrsb_16       xrsa_17   xrsb_17
# 2022-04-24 23:59:59  4.791470e-08  0.000001           NaN       NaN
# 2022-04-25 00:00:00  4.358424e-08  0.000001  6.129274e-08  0.000001
# 2022-04-25 00:00:01  5.654471e-08  0.000001  8.665445e-08  0.000001
# 2022-04-25 00:00:02  5.221424e-08  0.000001  6.223206e-08  0.000001
# 2022-04-25 00:00:03  5.437174e-08  0.000001  7.633447e-08  0.000001

# %%
### Raw data plots
ax= XRS.plot(logy=True)

# Add horizontals shaded region
ax.axhspan(10e-7,10e-6,color='green',alpha=0.2)
ax.axhspan(10e-6,10e-5,color='orange',alpha=0.2)
ax.axhspan(10e-5,10e-4,color='red',alpha=0.2)

ax.set_ylabel('Watts m$^2$')
ax.set_title('Raw data')

plt.savefig('Raw_data.pdf')

# %%
### Histograms : understand our data's distributions
#XRS.plot.hist(subplots=True)
XRS['xrsb_17'].plot.hist()
plt.savefig('hist_xrsb_17.pdf')

# %% [markdown]
# To get the percent change over a period, we can use .pct_change()

# %%
### Histogram of the percent changes over time 
XRS['xrsb_17'].pct_change().plot.hist(bins=30)
plt.savefig('pct_hist_xrsb_17.pdf')

# %%
XRS['xrsa_17'].pct_change().plot.hist(bins=30)
plt.savefig('pct_hist_xrsa_17.pdf')

# %%
#### Correlations
correlations = XRS.corr()

import seaborn as sns

#sns.heatmap(correlations>0.95, annot=True)
sns.heatmap(correlations, annot=True)
plt.savefig('corr_heatmap.pdf')

# %%
XRS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 86401 entries, 2022-04-24 23:59:59 to 2022-04-25 23:59:59
# Freq: S
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   xrsa_16  82781 non-null  float32
#  1   xrsb_16  82781 non-null  float32
#  2   xrsa_17  86400 non-null  float32
#  3   xrsb_17  86400 non-null  float32
# dtypes: float32(4)
# memory usage: 2.0 MB

# %%
#### MISSING VALUES
## .isna()
XRS.isnull().sum()
# Out:
# xrsa_16    3620
# xrsb_16    3620
# xrsa_17       1
# xrsb_17       1
# dtype: int64

# %%
### Percentage of missing
XRS.isnull().mean()*100
# Out:
# xrsa_16    4.189766
# xrsb_16    4.189766
# xrsa_17    0.001157
# xrsb_17    0.001157
# dtype: float64

# %%
### Scatter plots
_=pd.plotting.scatter_matrix(XRS, alpha=0.2, marker='+', s=2)
#for i, axs in enumerate(_):
    #for j, ax in enumerate(axs):
        #if i != j:  # only the scatter plots
            #ax.set_xscale('log')
            #ax.set_yscale('log')

# %%
plt.loglog(XRS['xrsb_16'],XRS['xrsb_17'])

# %%
# Create 8- % changes of xrsb 
#XRS['5d_future_close'] = XRS['xrsb_17'].shift(-8)
#XRS['5d_close_future_pct'] = XRS['5d_future_close'].pct_change(8)
#XRS['5d_close_pct'] = XRS['xrsb_17'].pct_change(8)

# Calculate the correlation matrix (current and future)
#corr = XRS[['5d_close_pct', '5d_close_future_pct']].corr()
#print(corr)

# Scatter the current 8- percent change vs the future 8- percent change
#plt.scatter(XRS['5d_close_pct'], XRS['5d_close_future_pct'])
#plt.show()

# %%
### Rolling average (to smooth the signal)

### The larger the window, the smoother the result will be
rolling = XRS.rolling(window=50).mean()

ax = rolling.plot(logy=True)

ax.axvspan('2022-04-25 01:00','2022-04-25 02:00',color='yellow',alpha=0.2)
ax.axvspan('2022-04-25 16:20','2022-04-25 17:00',color='yellow',alpha=0.2)

ax.axvline('2022-04-25 21:00', color='k', linestyle='--', alpha=0.6)
ax.axvline('2022-04-25 01:40', color='k', linestyle='--', alpha=0.6)

# %%
### Select first value 
first_values = XRS.iloc[1]

# Create normalized
normalized = XRS.div(first_values).mul(100)

# Plot normalized
normalized.plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
pct_change_xrs = XRS.pct_change()
#.mul(100)

pct_change_xrs.mul(100).plot(subplots=True, figsize=(12,8))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
correlations_change = pct_change_xrs.corr()

sns.heatmap(correlations_change, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Collapsing data into categories

# %%
# Create ranges for flare class
ranges = [10e-7,10e-6,10e-5,10e-4]
group_flare = ['C','M','X']

# Create flare_class column
XRS['flare_class'] = pd.cut(XRS['xrsb_17'], bins = ranges, labels = group_flare)

# %%
XRS['flare_class'].head()
# Out:
# 2022-04-24 23:59:59    NaN
# 2022-04-25 00:00:00      C
# 2022-04-25 00:00:01      C
# 2022-04-25 00:00:02      C
# 2022-04-25 00:00:03      C
# Freq: S, Name: flare_class, dtype: category
# Categories (3, object): ['C' < 'M' < 'X']

# %%
XRS['flare_class'].describe()
# Out:
# count     67673
# unique        2
# top           C
# freq      65994
# Name: flare_class, dtype: object

# %%
XRS['flare_class'].value_counts()
# Out:
# C    65994
# M     1679
# X        0
# Name: flare_class, dtype: int64

# %%
XRS.head()
# Out:
#                           xrsa_16   xrsb_16       xrsa_17   xrsb_17  \
# 2022-04-24 23:59:59  4.791470e-08  0.000001           NaN       NaN
# 2022-04-25 00:00:00  4.358424e-08  0.000001  6.129274e-08  0.000001
# 2022-04-25 00:00:01  5.654471e-08  0.000001  8.665445e-08  0.000001
# 2022-04-25 00:00:02  5.221424e-08  0.000001  6.223206e-08  0.000001
# 2022-04-25 00:00:03  5.437174e-08  0.000001  7.633447e-08  0.000001
#
#                     flare_class
# 2022-04-24 23:59:59         NaN
# 2022-04-25 00:00:00           C
# 2022-04-25 00:00:01           C
# 2022-04-25 00:00:02           C
# 2022-04-25 00:00:03           C

# %%
XRS.describe()
# Out:
#             xrsa_16       xrsb_16       xrsa_17       xrsb_17
# count  8.278100e+04  8.278100e+04  8.640000e+04  8.640000e+04
# mean   1.155584e-07  2.060005e-06  1.242380e-07  2.167254e-06
# std    2.136874e-07  2.045044e-06  2.105727e-07  2.056448e-06
# min    3.701339e-09  7.836830e-07  3.254926e-09  8.038184e-07
# 25%    3.492330e-08  9.909381e-07  3.804770e-08  1.032195e-06
# 50%    4.572627e-08  1.307867e-06  5.580739e-08  1.379904e-06
# 75%    7.676179e-08  2.017208e-06  9.508316e-08  2.322807e-06
# max    6.963651e-06  1.290409e-05  2.182573e-06  1.316155e-05

# %%
sns.scatterplot(x='xrsa_16', y='xrsa_17', hue='flare_class', data=XRS)
# Out:
# <AxesSubplot:xlabel='xrsa_16', ylabel='xrsa_17'>

# %%
tmp = pd.DataFrame()

### Promediar ruido
tmp['meanb'] = rolling[['xrsb_16', 'xrsb_17']].mean(axis=1)
tmp['meana'] = rolling[['xrsa_16', 'xrsa_17']].mean(axis=1)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 3))
ax1.plot(tmp['meanb'])
ax1.set(title="XRSB-LONG",yscale='log')
ax2.plot(tmp['meana'])
ax2.set(title="XRSA-SHORT",yscale='log')
# Out:
# [Text(0.5, 1.0, 'XRSA-SHORT'), None]

# %%
sns.pairplot(XRS, hue="flare_class")

# %%
### STD

### The larger the window, the smoother the result will be
xrstd = XRS.rolling(window=50).std()

ax = xrstd.plot(logy=True)

# %%
### MAX

### The larger the window, the smoother the result will be
xrsmax = XRS.rolling(window=50).max()

ax = xrsmax.plot(logy=True,grid=True)

# %% [markdown]
# #### Autocorrelation describes the relationship of a time series with its past values
#
# Compute the autocorrelation function for each datasets using the plot_acf function with 50 lags (and suppress the confidence intervals by setting alpha=1).
#
# * Correlation of a time series with a lagged copy of itself (mean Lag-one autocorrelation)
#      - Mean Reversion - Negative autocorrelation
#      - Trend following - Positive autocorrelation
#
# If autocorrelation values are close to 0, then values between consecutive observations are not correlated with one another. Inversely, autocorrelations values close to 1 or -1 indicate that there exists strong positive or negative correlations between consecutive observations, respectively.
#
# In order to help you asses how trustworthy these autocorrelation values are, the plot_acf() function also returns confidence intervals (represented as blue shaded regions). If an autocorrelation value goes beyond the confidence interval region, you can assume that the observed autocorrelation value is statistically significant.

# %%
# Compute and print the autocorrelation : This method computes the Pearson correlation between the Series and its shifted self.
autocorrelation = XRS['xrsb_17'].autocorr()
print("The autocorrelation of weekly returns is %4.2f" %(autocorrelation))
# Out:
# The autocorrelation of weekly returns is 1.00

# %%
# Import the plot_acf module from statsmodels
from statsmodels.graphics.tsaplots import plot_acf

# Plot 1: 
plot_acf(XRS['xrsb_17'].dropna(), alpha=1,lags=50)

# Plot 2: 
plot_acf(XRS['xrsa_17'].dropna(), lags=50)


# Plot 3: AR parameter = +0.3
#plot_acf(simulated_data_3, alpha=1, lags=20)
#plt.show()

# %% [markdown]
# In the autocorrelation plot above, are consecutive observations highly correlated (i.e superior to 0.5) and statistically significant? They are highly correlated and statistically significant.

# %% [markdown]
# ### Partial autocorrelation
#
# in time series data: removes the effect of previous time points.
#
# If partial autocorrelation values are close to 0, then values between observations and lagged observations are not correlated with one another. Inversely, partial autocorrelations with values close to 1 or -1 indicate that there exists strong positive or negative correlations between the lagged observations of the time series.
# The .plot_pacf() function also returns confidence intervals, which are represented as blue shaded regions. If partial autocorrelation values are beyond this confidence interval regions, then you can assume that the observed partial autocorrelation values are statistically significant.

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# Plot PACF for AR(1)
plot_pacf(XRS['xrsb_17'].dropna(),lags=50)

# Plot 2: 
plot_pacf(XRS['xrsa_17'].dropna(), lags=50)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1434: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# ### Stationarity
#
# #### Making time series stationary
#
# * Statistical tests for stationarity: The augmented Dicky-Fuller test(only tests for trend stationarity)
# Test for trend non-stationarity and Null hypothesis is time series is non stationary
#
# 0-> More negative means more likely to be stationary
#
# 1-> If p-value is small -> reject null hypothesis. Reject non-stationary
#
# 4-> the critical test statistics
#
# * Making a dataset stationary
#
#  - Taking the difference  $\Delta y_t = y_t-y_{t-1}$
#
#  - Other transforms: Take the log, Take the square root, Take the proportional change df.shift(1)/df

# %%
# Import augmented dicky-fuller test function
from statsmodels.tsa.stattools import adfuller

# Run test
result = adfuller(XRS['xrsb_16'].dropna())

# Print test statistic
print(result[0])

# Print p-value
print(result[1])

# Print critical values
print(result[4]) 

#print full results
print(result)
# Out:
# -4.738966678222479
# 7.105664094000862e-05
# {'1%': -3.4304290377317894, '5%': -2.8615749333588614, '10%': -2.566788593818515}
# (-4.738966678222479, 7.105664094000862e-05, 41, 82739, {'1%': -3.4304290377317894, '5%': -2.8615749333588614, '10%': -2.566788593818515}, -2771813.403771861)

# %%
# Run test
result = adfuller(XRS['xrsa_16'].dropna())

# Print test statistic
print(result[0])

# Print p-value
print(result[1])

# Print critical values
print(result[4]) 

#print full results
print(result)
# Out:
# -7.792350047951582
# 7.88052605233001e-12
# {'1%': -3.430429060665531, '5%': -2.8615749434950577, '10%': -2.566788599213685}
# (-7.792350047951582, 7.88052605233001e-12, 65, 82715, {'1%': -3.430429060665531, '5%': -2.8615749434950577, '10%': -2.566788599213685}, -2649717.3266170435)
